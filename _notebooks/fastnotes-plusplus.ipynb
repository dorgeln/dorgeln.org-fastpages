# %% [markdown]
# # Fastnotes++
# > "The hidden joys of dorgeln/fastnotes and making your own Docker image."
#
# - toc:false
# - badges: true
# - comments: true
# - author: Andreas Trawöger
# - categories: [fastnotes]
# - image: images/fastnotes-plusplus.gif
# - permalink: fastnotes-plusplus
# - published: true
# - hide: false
# - sticky_rank: 11

# %% [markdown]
# # It's only wafer thin
#
# One of the main motivations behind dorgeln/fastnotes was to create a Jupyter Docker image that's really optimized to be as small as possible. But I still couldn't resist the temptation to add a couple of small packages which can be summarized by the following Bash One-Liner .

# %%
# !asciinema rec -y --overwrite -c "echo;echo;echo;echo Running $DOCKER_USER/$DOCKER_REPO:$VERSION | lolcat -8;echo;echo;neofetch --stdout | lolcat -a -8;echo; echo Enjoy your data| lolcat -a -8;echo;echo;echo" neofetch.cast && ttygif --font PhoenixEGA_8x8 --input neofetch.cast --loop 0 --width 80 --height 25 --delay 1000 --output ../images/fastnotes-plusplus.gif;rm -v neofetch.cast
# Out:
# asciinema: recording asciicast to neofetch.cast
# asciinema: exit opened program when you're done
#
#
#
# Running dorgeln/fastnotes:0.0.16
#
#
# jovyan@jupyter-dorgeln-2dorbiter-2dzyqm6yozjovyan@jupyter-dorgeln-2dorbiter-2dzyqm6yozjovyan@jupyter-dorgeln-2dorbiter-2dzyqm6yozjovyan@jupyter-dorgeln-2dorbiter-2dzyqm6yozjovyan@jupyter-dorgeln-2dorbiter-2dzyqm6yozjovyan@jupyter-dorgeln-2dorbiter-2dzyqm6yozjovyan@jupyter-dorgeln-2dorbiter-2dzyqm6yozjovyan@jupyter-dorgeln-2dorbiter-2dzyqm6yozjovyan@jupyter-dorgeln-2dorbiter-2dzyqm6yozjovyan@jupyter-dorgeln-2dorbiter-2dzyqm6yozjovyan@jupyter-dorgeln-2dorbiter-2dzyqm6yoz
# ...
